# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import os
plt.rcParams['figure.figsize']=[16,8]

# %%
# !git clone https://github.com/brownethan/cs315.git
# Out:
# fatal: destination path 'cs315' already exists and is not an empty directory.

# %%
A=imread('cs315/HW08.jpg')
X=np.mean(A,-1);

# %%
img=plt.imshow(X)
img.set_cmap('gray')
plt.axis('off')
plt.show()

# %%
U, S, VT = np.linalg.svd(X,full_matrices=False)
S=np.diag(S)

# %%
k=10
Xapprox=U[:,:k] @ S[0:k,:k] @ VT[:k,:]
plt.figure(1)
img=plt.imshow(Xapprox)
img.set_cmap('gray')
plt.axis('off')
plt.title('k = '+str(k))
plt.show()

# %%
k=15
Xapprox=U[:,:k] @ S[0:k,:k] @ VT[:k,:]
plt.figure(1)
img=plt.imshow(Xapprox)
img.set_cmap('gray')
plt.axis('off')
plt.title('k = '+str(k))
plt.show()

# %%
k=20
Xapprox=U[:,:k] @ S[0:k,:k] @ VT[:k,:]
plt.figure(1)
img=plt.imshow(Xapprox)
img.set_cmap('gray')
plt.axis('off')
plt.title('k = '+str(k))
plt.show()

# %%
k=30
Xapprox=U[:,:k] @ S[0:k,:k] @ VT[:k,:]
plt.figure(1)
img=plt.imshow(Xapprox)
img.set_cmap('gray')
plt.axis('off')
plt.title('k = '+str(k))
plt.show()

# %%
k=60
Xapprox=U[:,:k] @ S[0:k,:k] @ VT[:k,:]
plt.figure(1)
img=plt.imshow(Xapprox)
img.set_cmap('gray')
plt.axis('off')
plt.title('k = '+str(k))
plt.show()

# %%
k=100
Xapprox=U[:,:k] @ S[0:k,:k] @ VT[:k,:]
plt.figure(1)
img=plt.imshow(Xapprox)
img.set_cmap('gray')
plt.axis('off')
plt.title('k = '+str(k))
plt.show()

# %%
k=200
Xapprox=U[:,:k] @ S[0:k,:k] @ VT[:k,:]
plt.figure(1)
img=plt.imshow(Xapprox)
img.set_cmap('gray')
plt.axis('off')
plt.title('k = '+str(k))
plt.show()
