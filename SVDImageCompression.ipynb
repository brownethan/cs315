# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import os
plt.rcParams['figure.figsize']=[16,8]

# %%
# !git clone https://github.com/brownethan/cs315.git
# Out:
# Cloning into 'cs315'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (91/91), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 91 (delta 47), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (91/91), 1.55 MiB | 4.57 MiB/s, done.
# Resolving deltas: 100% (47/47), done.

# %%
A=imread('cs315/HW08.jpg')
X=np.mean(A,-1);

# %%
img=plt.imshow(X)
img.set_cmap('gray')
plt.axis('off')
plt.show()

# %%
U, S, VT = np.linalg.svd(X,full_matrices=False)
S=np.diag(S)

# %%
k=20
Xapprox=U[:,:k] @ S[0:k,:k] @ VT[:k,:]
plt.figure(1)
img=plt.imshow(Xapprox)
img.set_cmap('gray')
plt.axis('off')
plt.title('k = '+str(k))
plt.show()
